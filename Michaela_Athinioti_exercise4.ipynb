# %% [markdown]
# <a href="https://colab.research.google.com/github/athiniotim/athiniotim/blob/main/Michaela_Athinioti_exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Άσκηση 1
#
# Γράψτε ένα προγραμματάκι που θα αθροίζει όλους τους περιττούς αριθμούς από το 1 έως και το 100 και θα τυπώνει το τελικό άθροισμα.
#
# Hints & tips:
#
# - περιττοί είναι οι αριθμοί που το υπόλοιπο της διαίρεσής τους με το 2 ΔΕΝ είναι 0 (x % 2 != 0)
# - μπορούμε αρχικά να ορίσουμε ότι το άθροισμα των περιττών αριθμών είναι 0 (sum = 0)
# - στη συνέχεια μπορούμε να φτιάξουμε μια λούπα που θα κάνει τα εξής:
#   - για κάθε αριθμό από το 1 ως και το 100
#   - αν το υπόλοιπο της διαίρεσης του αριθμού με το 2 δεν είναι 0
#   - το άθροισμα θα αυξάνεται κατά τον αριθμό

# %%
sum = 0
for x in range(1, 101):
  if x % 2 != 0:
    sum += x
print(sum)
# Out:
# 2500

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 2
#
# Τροποποιήστε το παραπάνω πρόγραμμα έτσι ώστε, εκτός από το άθροισμα των περιττών, να υπολογίζει και να τυπώνει ΚΑΙ:
# - το πλήθος των περιττών αριθμών
# - το άθροισμα των ζυγών αριθμών στο ίδιο εύρος
# - το πλήθος των ζυγών αριθμών

# %%
sum_perittoi = 0
sum_artioi = 0
length_perittoi = 0
length_artioi = 0
for x in range(1, 101):
  if x % 2 != 0:
    sum_perittoi += x
    length_perittoi += 1
  else:
    sum_artioi += x
    length_artioi += 1
print("Το άρθροισμα των περιττών είναι:", sum_perittoi, "και το πλήθος των περιττών είναι:", length_perittoi)
print("Το άρθροισμα των άρτιων είναι:", sum_artioi, "και το πλήθος των άρτιων είναι:", length_artioi)
# Out:
# Το άρθροισμα των περιττών είναι: 2500 και το πλήθος των περιττών είναι: 50
# Το άρθροισμα των άρτιων είναι: 2550 και το πλήθος των άρτιων είναι: 50

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3
#
# Αντιγράψτε εδώ τον κώδικα που γράψατε για την 1η Άσκηση του notebook "exercise3.ipynb".
#
# Θα χρειαστούμε τη λίστα με τα λεξικά των άρθρων.
#
# Χρησιμοποιώντας τη βιβλιοθήκη Pandas, φτιάξτε ένα dataframe με τα δεδομένα της λίστας με τα λεξικά των άρθρων.
# Στη συνέχεια, εμφανίστε το dataframe στην οθόνη.
#
# **Hints & tips**:
# - για να χρησιμοποιήσετε τη βιβλιοθήκη pandas πρέπει πρώτα να την εισάγετε: import pandas as pd
# - η δημιουργία ενός dataframe από μια λίστα με λεξικά, γίνεται με την εξής σύνταξη: df = pd.DataFrame(<όνομα λίστας με λεξικά>)

# %%
articles_data = []
article1 = { "Τίτλος" : 'Τέμπη: Τελικά πόσοι άνθρωποι βρέθηκαν στο Σύνταγμα', 'Ημερομηνία' : "01/03/2025", 'Κατηγορία' : "Κοινωνία", 'url' : 'https://www.tanea.gr/2025/03/01/greece/tempi-telika-posoi-anthropoi-vrethikan-sto-syntagma-2/'}
article2 = { "Τίτλος" : 'Ντράπηκε και η ντροπή με το μήνυμα Μητσοτάκη για τα Τέμπη', 'Ημερομηνία' : "28.02.25", 'Κατηγορία' : "Κοινωνία", 'url' : 'https://www.efsyn.gr/politiki/kybernisi/464626_ntrapike-kai-i-ntropi-me-minyma-mitsotaki-gia-ta-tempi#goog_rewarded'}
articles_data.append(article1)
articles_data.append(article2)
articles_data[0]["Πηγή"] = "ΤΑ ΝΕΑ"
articles_data[1]["Πηγή"] = "efsyn"

# %%
import pandas as pd

# %%
df = pd.DataFrame(articles_data)
df
# Out:
#                                               Τίτλος  Ημερομηνία Κατηγορία  \
# 0  Τέμπη: Τελικά πόσοι άνθρωποι βρέθηκαν στο Σύντ...  01/03/2025  Κοινωνία
# 1  Ντράπηκε και η ντροπή με το μήνυμα Μητσοτάκη γ...    28.02.25  Κοινωνία
#
#                                                  url    Πηγή
# 0  https://www.tanea.gr/2025/03/01/greece/tempi-t...  ΤΑ ΝΕΑ
# 1  https://www.efsyn.gr/politiki/kybernisi/464626...   efsyn

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 4 (intro)
#
# Στο site "ourworldindata.org" παρέχονται πάρα πολλά δεδομένα και γραφήματα για διάφορα topics για όλες τις χώρες του κόσμου.
#
# Για παράδειγμα, στη σελίδα https://ourworldindata.org/explorers/covid?Metric=Excess+mortality+%28estimates%29&Interval=Cumulative&Relative+to+population=false&country=USA~BRA~JPN~DEU, παρέχονται δεδομένα και γραφήματα σχετικά με την Covid-19.
#
# Αν επισκεφθείτε την παραπάνω σελίδα, επάνω αριστερά, υπάρχει ένας υπερσύνδεσμος με το κείμενο "Download this dataset". Εάν τον πατήσετε θα οδηγηθείτε στη σελίδα με τα datasets για τον covid.
#
# Πιο κάτω, σ' αυτή τη σελίδα, υπάρχει η ενότητα "Download data", με πολλά κουμπάκια download.
#
# Όταν πατήσετε κάποιο download μεταφέρεστε στη σελίδα του raw αρχείου csv με τα δεδομένα.
#
# Μπορούμε να φέρουμε αυτά τα δεδομένα σε ένα dataframe στην Python, με την παρακάτω εντολή:

# %%
covid_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/cases_deaths/cases_deaths.csv")
covid_df
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 471245     Zimbabwe  2025-02-26        0.0       266410         0.0
# 471246     Zimbabwe  2025-02-27        0.0       266410         0.0
# 471247     Zimbabwe  2025-02-28        0.0       266410         0.0
# 471248     Zimbabwe  2025-03-01        0.0       266410         0.0
# 471249     Zimbabwe  2025-03-02        0.0       266410         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# 0                  0           NaN            NaN                      NaN
# 1                  0           NaN            NaN                      NaN
# 2                  0           NaN            NaN                      NaN
# 3                  0           NaN            NaN                      NaN
# 4                  0           NaN            NaN                      NaN
# ...              ...           ...            ...                      ...
# 471245          5740           0.0            0.0                      NaN
# 471246          5740           0.0            0.0                      NaN
# 471247          5740           0.0            0.0                      NaN
# 471248          5740           0.0            0.0                      NaN
# 471249          5740           0.0            0.0                      NaN
#
#         weekly_pct_growth_deaths  ...  cfr_100_cases  cfr_short_term  \
# 0                            NaN  ...            NaN             NaN
# 1                            NaN  ...            NaN             NaN
# 2                            NaN  ...            NaN             NaN
# 3                            NaN  ...            NaN             NaN
# 4                            NaN  ...            NaN             NaN
# ...                          ...  ...            ...             ...
# 471245                       NaN  ...       2.154574             NaN
# 471246                       NaN  ...       2.154574             NaN
# 471247                       NaN  ...       2.154574             NaN
# 471248                       NaN  ...       2.154574             NaN
# 471249                       NaN  ...       2.154574             NaN
#
#         days_since_100_total_cases  days_since_5_total_deaths  \
# 0                            -86.0                      -91.0
# 1                            -85.0                      -90.0
# 2                            -84.0                      -89.0
# 3                            -83.0                      -88.0
# 4                            -82.0                      -87.0
# ...                            ...                        ...
# 471245                      1737.0                     1819.0
# 471246                      1738.0                     1820.0
# 471247                      1739.0                     1821.0
# 471248                      1740.0                     1822.0
# 471249                      1741.0                     1823.0
#
#         days_since_1_total_cases_per_million  \
# 0                                      -81.0
# 1                                      -80.0
# 2                                      -79.0
# 3                                      -78.0
# 4                                      -77.0
# ...                                      ...
# 471245                                1779.0
# 471246                                1780.0
# 471247                                1781.0
# 471248                                1782.0
# 471249                                1783.0
#
#         days_since_0_1_total_deaths_per_million  \
# 0                                         -91.0
# 1                                         -90.0
# 2                                         -89.0
# 3                                         -88.0
# 4                                         -87.0
# ...                                         ...
# 471245                                   1819.0
# 471246                                   1820.0
# 471247                                   1821.0
# 471248                                   1822.0
# 471249                                   1823.0
#
#         days_since_100_total_cases_and_5m_pop  total_deaths_last12m  \
# 0                                       -86.0                   NaN
# 1                                       -85.0                   NaN
# 2                                       -84.0                   NaN
# 3                                       -83.0                   NaN
# 4                                       -82.0                   NaN
# ...                                       ...                   ...
# 471245                                 1737.0                   0.0
# 471246                                 1738.0                   0.0
# 471247                                 1739.0                   0.0
# 471248                                 1740.0                   0.0
# 471249                                 1741.0                   0.0
#
#         total_deaths_per_100k_last12m  total_deaths_per_million_last12m
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 471245                            0.0                               0.0
# 471246                            0.0                               0.0
# 471247                            0.0                               0.0
# 471248                            0.0                               0.0
# 471249                            0.0                               0.0
#
# [471250 rows x 40 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 4 (actual part)
#
# Βρείτε από το ourworldindata.org ένα dataset που σας ενδιαφέρει και ανοίξτε το σαν dataframe.

# %%
df_vaccinations = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/vaccinations_age/vaccinations_age.csv")
df_vaccinations
# Out:
#          country age_group        date  people_vaccinated_per_hundred  \
# 0      Argentina      100+  2020-01-01                           0.00
# 1      Argentina      100+  2020-01-02                           0.00
# 2      Argentina      100+  2020-01-03                           0.00
# 3      Argentina      100+  2020-01-04                           0.00
# 4      Argentina      100+  2020-01-05                           0.00
# ...          ...       ...         ...                            ...
# 74137    Uruguay       75+  2021-05-28                          86.42
# 74138    Uruguay       75+  2021-06-11                          86.63
# 74139    Uruguay       75+  2021-06-18                          86.96
# 74140    Uruguay       75+  2021-06-25                          87.56
# 74141    Uruguay       75+  2021-07-09                          88.18
#
#        people_fully_vaccinated_per_hundred  people_with_booster_per_hundred
# 0                                     0.00                              0.0
# 1                                     0.00                              0.0
# 2                                     0.00                              0.0
# 3                                     0.00                              0.0
# 4                                     0.00                              0.0
# ...                                    ...                              ...
# 74137                                31.56                              NaN
# 74138                                51.68                              NaN
# 74139                                57.31                              NaN
# 74140                                66.62                              NaN
# 74141                                74.81                              NaN
#
# [74142 rows x 6 columns]
